# %% [markdown]
# # **TASK 1**
# Write a function called even_checker that takes a number as an argument and prints whether the number is even or odd inside the function.
#
# ===================================================================
#
# Example 1:
#
# Function Call:
#
# even_checker(5)
#
# Output:
#
# Odd!!
#
# ===================================================================
#
# Example2:
#
# Function Call:
#
# even_checker(2)
#
# Output:
#
# Even!!

# %%
def even_checker(num):
    if num % 2 == 0:
        print('even!!')
    else:
        print('odd!!')
even_checker(2)
# Out:
# even!!

# %% [markdown]
# # **TASK 2**
#
# Write a python function that takes the limit as an argument of the Fibonacci series and prints till that limit.
#
# ===================================================================
#
# Function Call:
#
# fibonacci(10)
#
# Output:
#
# 0 1 1 2 3 5 8
#
# ===================================================================
#
# Function Call:
#
# fibonacci(5)
#
# Output:
#
# 0 1 1 2 3 5

# %%
def fib(num):
    val_1 = 0
    val_2 = 1
    ans = 0
    print(val_1, end=' ')
    while val_2 <= num :
        print(val_2, end=' ')
        ans = val_1 + val_2
        val_1 = val_2
        val_2 = ans
fib(5)
# Out:
# 0 1 1 2 3 5

# %%
#TASK 3
def foo_moo(num):
    if (num % 2 == 0) and (num % 3 == 0) :
        return('FooMoo')
    elif num % 3 == 0 :
        return('Moo')
    elif (num % 2 == 0):
        return('Foo')
    else:
        return('Boo')
print(foo_moo(24))
# Out:
# FooMoo

# %%
# TASK 4
def funtion_name(data):
    count_upper = 0
    count_lower = 0
    for itaretion in data:
        if itaretion != ' ':
            if itaretion >= 'A' and itaretion <= 'Z':
                count_upper = count_upper + 1
            elif itaretion >= 'a' and itaretion <= 'z':
                count_lower = count_lower + 1
    print('No. of Uppercase characters: ',count_upper)
    print('No. of Lowercase Characters: ',count_lower)
funtion_name('The quick Sand Man')
# Out:
# No. of Uppercase characters:  3
# No. of Lowercase Characters:  12

# %%
# TASK 5
def calculate_tax(age, salary, designation):
    if age < 18 or salary < 10000 or designation == 'PRESIDENT':
        tax = salary * 0
        return(tax)
    elif age >= 18 and salary >= 10000 and designation != 'PRESIDENT':
        if salary >= 10000 and salary <= 20000:
            tax = salary * (5 / 100)
            return(tax)
        if salary > 20000:
            tax = salary * (10 / 100)
            return(tax)
age = int(input('enter the age: '))
salary = int(input('enter the salary: '))
designation = input('enter the designation: ').upper()
print(calculate_tax(age, salary, designation))
# Out:
# enter the age: 20
# enter the salary: 18000
# enter the designation: assistant manager
# 900.0

# %% [markdown]
# TASK 6

# %%
# TASK 6
days = int(input('enter the number of days: '))
def function_name(days):
    years = days // 360
    months = days % 12
    days = (days % 365) % 30
    return(years, months, days)
print(function_name(days))
# Out:
# enter the number of days: 4330
# (12, 10, 15)

# %% [markdown]
# TASK 7

# %%
# TASK 7
def show_palindrome(num):
    val = ''
    for itaretion in range(1, num, 1):
        val = val + str(itaretion)
    for itaretion in range(num, 0, -1):
        val = val + str(itaretion)
    return(val)
print(show_palindrome(5))
# Out:
# 123454321

# %% [markdown]
# TASK 8

# %%
def show_palindromic_triangle(num):
    for count in range(1, num+1, 1):
      for space in range(num - count):
        print(' ', end=' ')
      for itaretion in range(1, count+1):
        print(itaretion, end=' ')
      for itaretion_2 in range(1, count):
        print(count - itaretion_2, end=' ')
      print()     
(show_palindromic_triangle(5))
# Out:
#         1
#       1 2 1
#     1 2 3 2 1
#   1 2 3 4 3 2 1
# 1 2 3 4 5 4 3 2 1

# %% [markdown]
# TASK 9

# %%
#TASK 9
def area_circumference_generator(radius):
    area = 3.141592653589793 * (radius ** 2)
    circumference = 2 * 3.141592653589793 * radius
    tuple_a = (area, circumference)
    var_a, var_b = tuple_a
    print(tuple_a)
    print('Area of the circle is', var_a, 'and circumference is', var_b)
    return('')
print(area_circumference_generator(1))
# Out:
# (3.141592653589793, 6.283185307179586)
# Area of the circle is 3.141592653589793 and circumference is 6.283185307179586

# %% [markdown]
# TASK 10

# %%
#TASK 10
def make_square(start, end):
    dict_a = {}
    for itaretion in range(start, end + 1, 1):
        key = itaretion
        val = itaretion ** 2
        dict_a[key] = val
    return(dict_a)
print(make_square(1, 3))
# Out:
# {1: 1, 2: 4, 3: 9}

# %% [markdown]
# TASK 11

# %%
#TASK 11
def rem_duplicate(tuple_a):
    list_a = []
    list_b = []
    for itaretion in tuple_a:
        if itaretion not in list_b:
            list_b.append(itaretion)
        elif itaretion not in list_b:
            list_b.append(itaretion)
    tuple_b = tuple(list_b)
    return(tuple_b)
print(rem_duplicate((1,1,1,2,3,4,5,6,6,6,6,4,0,0,0)))
# Out:
# (1, 2, 3, 4, 5, 6, 0)

# %% [markdown]
# TASK 12

# %%
#TASK 12
def rem_duplicate(tuple_a):
    list_a = []
    list_b = []
    for itaretion in tuple_a:
        if itaretion not in list_b:
            list_b.append(itaretion)
        elif itaretion not in list_a:
            list_a.append(itaretion)
    list_b.extend(list_a)
    list_b.sort()
    return(list_b)
print(rem_duplicate([1, 2, 3, 3, 3, 3, 4, 5, 8, 8]))
# Out:
# [1, 2, 3, 3, 4, 5, 8, 8]

# %% [markdown]
# TASK 13

# %%
#TASK 13
def basic_calculation(oparetor, first_num, second_num):
    if oparetor == '+':
      ans = first_num + second_num
      return(float(ans))
    elif oparetor == '-':
      ans = first_num - second_num
      return(float(ans))
    elif oparetor == '*':
      ans = first_num * second_num
      return(float(ans))
    elif oparetor == '/':
      ans = first_num / second_num
      return(float(ans))
oparetor = input('enter the oparetor: ')
first_num = int(input('enter the frist number: '))
second_num = int(input('enter the second number: '))
print(basic_calculation(oparetor, first_num, second_num))
# Out:
# enter the oparetor: +
# enter the frist number: 10
# enter the second number: 20
# 30.0

# %% [markdown]
# TASK 14

# %%
#TASK 14
def word_remove(sentence, position):
    data = ''
    for itaretion in sentence:
        if itaretion != sentence[position]:
            data = data + itaretion
            
    return(data)

sentence = input('enter the sentence: ')
position = int(input('enter the position: '))
print(word_remove(sentence, position))
# Out:
# enter the sentence: I love programming.
# enter the position: 3
# I lve prgramming.

# %%
#TASK 15
def grocery_shop(items, loc = 'dhammondi'):
    total = 0
    shop = {'Rice' : 105, 'Potato' : 20, 'Chiken' : 250, 'Beef' : 510, 'Oil' : 85}
    for item in items:
        total = total + shop[item]
    if loc.lower() == 'dhammondi':
        total = total + 30
    else:
        total = total + 70
    return(total)
print(grocery_shop(["Rice", "Beef", "Rice"], "Mohakhali"))
# Out:
# 790

# %%
x = 0
y = 0
sum = 0
while (x < 10):
  y = x - 3
  while (y < 3):
    sum = x - y * 2 
    print(sum)
    y = y + 1
  if (x > 7): 
    x += 1
  else: 
    x += 3
sum = x - y * 2
print(sum)
# Out:
# 6
# 4
# 2
# 0
# -2
# -4
# 3
# 1
# -1
# -2

# %%
x = 0
p = 0
sum = 0
p = 1
x = 2
q = 0.0
sum = 0
while (p < 12):
  q = x + p - (sum + int(5 / 3)) / 3.0 % 2
  sum = sum + x + int(q)
  x+=1
  print(q)
  print(sum)
  if (x > 5):
    p += int(4 / 2)
  else:
    p += 3 % 1
sum = sum + p
print(sum)
# Out:
# 2.6666666666666665
# 4
# 2.333333333333333
# 9
# 3.6666666666666665
# 16
# 4.333333333333333
# 25
# 8.333333333333334
# 39
# 10.666666666666666
# 56
# 14.0
# 78
# 17.666666666666668
# 104
# 20.0
# 134
# 147

# %%
#TASK 16
x = 0
y = 0
sum = 0
p = 0.0
while (x < 9):
    y = x/2
    while (y<x):
        p = (x + 5.0)/ 2
        sum = sum+ 2 + x + y*2 + int(p)
        print(sum)
        y=y+1
    x = x+2
    if (x>5):
        sum = 2
    else:
        sum += 3
# Out:
# 12.0
# 29.0
# 45.0
# 21.0
# 42.0
# 65.0
# 26.0
# 52.0
# 80.0
# 110.0

# %%
#TASK 17
x = 0
y = 0
sum = 0
while (x < 10):
  y = x - 3
  y = 40
  while (y > 22):
    if ((sum > 30) and (sum < 40)):
      sum = sum + x * 2
    elif((sum > 40) and (sum < 50)):
      sum = sum + x * 3
    else:
      sum = sum + 23
    print(sum)
    y = y - 10
  x += 2
# Out:
# 23
# 46
# 52
# 75
# 98
# 121
# 144
# 167
# 190
# 213

# %%
#TASK 20
i = 2
j = 0
k = 17
test = "-->dog"
while i < 7:
  k-=1
  j = k
  while j > 12:
    if (j % 2 == 0):
      test += "<--"
      test = test + str(i) + str(j // 2)
    else:
      test += "-->"
      test = test + str(i // 2) + str(j) 
    print(test)
    j-=1
  i+=1
# Out:
# -->dog<--28
# -->dog<--28-->115
# -->dog<--28-->115<--27
# -->dog<--28-->115<--27-->113
# -->dog<--28-->115<--27-->113-->115
# -->dog<--28-->115<--27-->113-->115<--37
# -->dog<--28-->115<--27-->113-->115<--37-->113
# -->dog<--28-->115<--27-->113-->115<--37-->113<--47
# -->dog<--28-->115<--27-->113-->115<--37-->113<--47-->213
# -->dog<--28-->115<--27-->113-->115<--37-->113<--47-->213-->213

# %%
#TASK 21
test = ""
i = 5
j = 0
k = 15
while (i< 10): 
    k-=1
    j = k
    while (j > 10 ):
        if j % 2 == 0:
            test = "<--"
            test = test + str(i) + '3' + "-->" + str(j // 3)
        else:
            test = "-->"
            test = "-->" + str((i // 3)) + test + str(j)
        print(test)
        j -=1
    i+=1
# Out:
# <--53-->4
# -->1-->13
# <--53-->4
# -->1-->11
# -->2-->13
# <--63-->4
# -->2-->11
# <--73-->4
# -->2-->11
# -->2-->11

# %%
#TASK 22
i = 10
while(i >= -20):
  if(i < 0):
    test = " != "
    test = str(i//2) + test + str(int(i/2))
  else:
    test = " == "
    test = str(i//2) + test + str(int(i/2))
  print(test)
  i -= 5
# Out:
# 5 == 5
# 2 == 2
# 0 == 0
# -3 != -2
# -5 != -5
# -8 != -7
# -10 != -10

# %%
-5/2
# Out:
# -2.5
